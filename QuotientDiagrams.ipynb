# %%
P = Graphics()

theta = var('theta')

r = 0.75

P += parametric_plot((r*cos(theta),r*sin(theta)),
                     (theta,0,2*pi),
                     thickness=4,
                     color='black')

P[-1].set_zorder(5)

for n in range(6):
    theta_p = n*2*pi/6
    c = 'red' if n % 2 == 0 else 'blue'
    P += point( (r*cos(theta_p),r*sin(theta_p)), color=c, size=160)
    P[-1].set_zorder(10)
    P += text("$t_%d$" % (1+(n % 2)),
              (1.15*r*cos(theta_p),1.15*r*sin(theta_p)),
              color='black',
              fontsize='xx-large')

for n in range(3):
    theta_p = n*2*pi/6
    P += line2d( [(r*cos(theta_p),r*sin(theta_p)),
                  (r*cos(theta_p+pi),r*sin(theta_p+pi))],
                color='black',
                linestyle=":")

############################

r_text = 1.2

theta_p = 0*2*pi/3

P += point( (r*cos(theta_p+pi/15), r*sin(theta_p+pi/15) ), color='purple', size=160)
P[-1].set_zorder(10)
P += text("$\hat{x}_{123}$",
          (r_text*r*cos(theta_p+pi/15), r_text*r*sin(theta_p+pi/15) ),
          color='black',
          fontsize='xx-large')

P += point( (r*cos(theta_p-pi/15), r*sin(theta_p-pi/15) ), color='purple', size=160)
P[-1].set_zorder(10)
P += text("$\hat{x}_{213}$",
          (r_text*r*cos(theta_p-pi/15), r_text*r*sin(theta_p-pi/15) ),
          color='black',
          fontsize='xx-large')

############################

theta_p = 1*2*pi/3

P += point( (r*cos(theta_p+pi/15), r*sin(theta_p+pi/15) ), color='purple', size=160)
P[-1].set_zorder(10)
P += text("$\hat{x}_{312}$",
          (r_text*r*cos(theta_p+pi/15), r_text*r*sin(theta_p+pi/15) ),
          color='black',
          fontsize='xx-large')

P += point( (r*cos(theta_p-pi/15), r*sin(theta_p-pi/15) ), color='purple', size=160)
P[-1].set_zorder(10)
P += text("$\hat{x}_{132}$",
          (r_text*r*cos(theta_p-pi/15), r_text*r*sin(theta_p-pi/15) ),
          color='black',
          fontsize='xx-large')

############################

theta_p = 2*2*pi/3

P += point( (r*cos(theta_p+pi/15), r*sin(theta_p+pi/15) ), color='purple', size=160)
P[-1].set_zorder(10)
P += text("$\hat{x}_{231}$",
          (r_text*r*cos(theta_p+pi/15), r_text*r*sin(theta_p+pi/15) ),
          color='black',
          fontsize='xx-large')

P += point( (r*cos(theta_p-pi/15), r*sin(theta_p-pi/15) ), color='purple', size=160)
P[-1].set_zorder(10)
P += text("$\hat{x}_{321}$",
          (r_text*r*cos(theta_p-pi/15), r_text*r*sin(theta_p-pi/15) ),
          color='black',
          fontsize='xx-large')


P.show(figsize=7,axes=False,aspect_ratio=1)
# Out:
# Graphics object consisting of 28 graphics primitives

# %%
P.save(os.path.join(SAGE_TMP, 'reducedX313.pdf'),axes=False,aspect_ratio=1)

# %%
P = Graphics()

fs = "xx-large"

P += text("$\overline{\mathcal{X}}_{3,1,3}/S_3$",
          (1.15,-2),
          color='black',
          fontsize=fs)

P += text("$\overline{\mathcal{X}}_{3,1,3}$",
          (1.15,1),
          color='black',
          fontsize=fs)


P += point( (0,-2), color= 'red', size=160)
P += point( (1,-2), color='blue', size=160)
P += line2d( [(0,-2),
              (1,-2)],
             color='black',
             thickness=4)
P[-1].set_zorder(-1)

P += point( (0.25,-2), color='purple', size=160 )
P += text("$x$",
          (0.25,-2.2),
          color='black',
          fontsize=fs)


for n in range(3):
    P += point( (0,n), color= 'red', size=160)
    P += point( (1,n), color='blue', size=160)
    P += line2d( [(0,n), (1,n)],
                color='black',
                thickness=4)
    P[-1].set_zorder(-1)

    P += line2d([(0, n), (1, (n+1)%3)],
                color='black',
                thickness=4)
    P[-1].set_zorder(-1)
    
    

P += point( (0.25,0), color='purple', size=160 )
P += text("$\hat{x}_{123}$",
          (0.25,0-0.2),
          color='black',
          fontsize=fs)

P += point( (0.25,1), color='purple', size=160 )
P += text("$\hat{x}_{231}$",
          (0.25,1-0.2),
          color='black',
          fontsize=fs)

P += point( (0.25,2), color='purple', size=160 )
P += text("$\hat{x}_{312}$",
          (0.25,2-0.2),
          color='black',
          fontsize=fs)


P += point( (0.25,0+0.25), color='purple', size=160 )
P += text("$\hat{x}_{213}$",
          (0.19,0.4),
          color='black',
          fontsize=fs)


P += point( (0.25,1+0.25), color='purple', size=160 )
P += text("$\hat{x}_{321}$",
          (0.19,1.4),
          color='black',
          fontsize=fs)


P += point( (0.25,1.5), color='purple', size=160 )
P += text("$\hat{x}_{132}$",
              (0.33,1.6),
              color='black',
              fontsize=fs)
    
    
P += arrow((0.5,-0.3),(0.5,-1.7),
           color='black')


P += text("$t_1$",
          (0,2.5),
          color='black',
          fontsize=fs)

P += text("$t_2$",
          (1,2.5),
          color='black',
          fontsize=fs)

P.show(figsize=7,axes=False)
# Out:
# Graphics object consisting of 34 graphics primitives

# %%
P.save(os.path.join(SAGE_TMP, 'quotientMapX313.pdf'),axes=False)
